# %% [markdown]
# Introduction to Pandas in Python
# 1. What is Pandas?
# Pandas is an open-source data analysis and data manipulation library for Python. It provides powerful data structures such as Series and DataFrame, which allow for efficient handling and analysis of structured data.
#
# Pandas is built on top of NumPy and is widely used for data preprocessing, cleaning, transformation, and analysis in data science and machine learning.
#
# Introduction to NumPy
# What is NumPy?
# NumPy (Numerical Python) is a powerful Python library used for numerical computing. It provides support for multi-dimensional arrays and mathematical functions, making it an essential library for handling structured data before using Pandas.
#
# Why NumPy?
# 1.Faster than Python lists for numerical operations
#
# 2.Efficient array manipulations

# %% [markdown]
# **Installing NumPy**
# If you haven’t installed NumPy, you can do so using:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)

# %% [markdown]
# Importing NumPy

# %%
import numpy as np

# %% [markdown]
# **Creating a NumPy Array**

# %%
arr = np.array([1, 2, 3, 4, 5])
print("NumPy Array:", arr)
# Out:
# NumPy Array: [1 2 3 4 5]

# %% [markdown]
# Basic Operations with NumPy

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
print("Array + 4:", arr + 4)  # Adds 5 to each element
print("Array * 2:", arr * 2)  # Multiplies each element by 2
print("Mean of array:", np.mean(arr))  # Calculates mean
print("Standard Deviation:", np.std(arr))  # Calculates standard deviation
# Out:
# Array + 4: [14 24 34 44 54]
# Array * 2: [ 20  40  60  80 100]
# Mean of array: 30.0
# Standard Deviation: 14.142135623730951

# %% [markdown]
# 2. Installing and Importing Pandas
# Installing Pandas (if not already installed)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Importing the Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Checking Pandas Version

# %%
print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 2.2.2

# %% [markdown]
# 3. Loading Data into a Pandas DataFrame
#
#
# Reading a CSV File into a DataFrame

# %%
df=pd.read_csv("/content/countries.csv")

# %%
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %% [markdown]
# 4. Exploring the DataFrame
#
# Displaying Data

# %%
df.head(100)
# Out:
#            country     native_name iso2 iso3   population       area  \
# 0      Afghanistan       افغانستان   AF  AFG   26023100.0   652230.0
# 1          Albania       Shqipëria   AL  ALB    2895947.0    28748.0
# 2          Algeria         الجزائر   DZ  DZA   38700000.0  2381741.0
# 3   American Samoa  American Samoa   AS  ASM      55519.0      199.0
# 4           Angola          Angola   AO  AGO   24383301.0  1246700.0
# ..             ...             ...  ...  ...          ...        ...
# 95           Japan              日本   JP  JPN  127080000.0   377930.0
# 96          Jersey          Jersey   JE  JEY      99000.0      116.0
# 97          Jordan          الأردن   JO  JOR    6666960.0    89342.0
# 98      Kazakhstan       Қазақстан   KZ  KAZ   17377800.0  2724900.0
# 99           Kenya           Kenya   KE  KEN   41800000.0   580367.0
#
#          capital  capital_lat  capital_lng                     region  \
# 0          Kabul    34.526011    69.177684  Southern and Central Asia
# 1         Tirana    41.326873    19.818791            Southern Europe
# 2        Algiers    36.775361     3.060188            Northern Africa
# 3      Pago Pago   -14.275479  -170.704830                  Polynesia
# 4         Luanda    -8.827270    13.243951             Central Africa
# ..           ...          ...          ...                        ...
# 95         Tokyo    35.682839   139.759455               Eastern Asia
# 96  Saint Helier    47.384387     4.683325                        NaN
# 97         Amman    31.951569    35.923962                Middle East
# 98        Astana    51.128220    71.430668  Southern and Central Asia
# 99       Nairobi    -1.283253    36.817245             Eastern Africa
#
#    continent
# 0       Asia
# 1     Europe
# 2     Africa
# 3    Oceania
# 4     Africa
# ..       ...
# 95      Asia
# 96       NaN
# 97      Asia
# 98      Asia
# 99    Africa
#
# [100 rows x 11 columns]

# %%
df.tail(100)
# Out:
#                country       native_name iso2 iso3  population       area  \
# 114         Madagascar      Madagasikara   MG  MDG  21842167.0   587041.0
# 115             Malawi            Malawi   MW  MWI  15805239.0   118484.0
# 116           Malaysia          Malaysia   MY  MYS  30430500.0   330803.0
# 117           Maldives          Maldives   MV  MDV    341256.0      300.0
# 118               Mali              Mali   ML  MLI  15768000.0  1240192.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#           capital  capital_lat  capital_lng                     region  \
# 114  Antananarivo   -18.910012    47.525581             Eastern Africa
# 115      Lilongwe   -13.987511    33.768144             Eastern Africa
# 116  Kuala Lumpur     3.151696   101.694237             Southeast Asia
# 117          Malé    16.370036    -2.290024  Southern and Central Asia
# 118        Bamako    12.605033    -7.986514             Western Africa
# ..            ...          ...          ...                        ...
# 209      Mata-Utu   -13.282042  -176.174022                  Polynesia
# 210      El Aaiún    27.154512   -13.195392            Northern Africa
# 211        Sana'a    15.353857    44.205884                Middle East
# 212        Lusaka   -15.416449    28.282154             Eastern Africa
# 213        Harare   -17.831773    31.045686             Eastern Africa
#
#     continent
# 114    Africa
# 115    Africa
# 116      Asia
# 117      Asia
# 118    Africa
# ..        ...
# 209   Oceania
# 210    Africa
# 211      Asia
# 212    Europe
# 213    Africa
#
# [100 rows x 11 columns]

# %% [markdown]
# Checking DataFrame Information

# %%
print("dataframe Info:")
df.info()
# Out:
# dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      214 non-null    object
#  1   native_name  213 non-null    object
#  2   iso2         213 non-null    object
#  3   iso3         214 non-null    object
#  4   population   210 non-null    float64
#  5   area         207 non-null    float64
#  6   capital      212 non-null    object
#  7   capital_lat  212 non-null    float64
#  8   capital_lng  212 non-null    float64
#  9   region       205 non-null    object
#  10  continent    206 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 18.5+ KB

# %% [markdown]
# Summary Statistics

# %%
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#          population          area  capital_lat  capital_lng
# count  2.100000e+02  2.070000e+02   212.000000   212.000000
# mean   3.365144e+07  6.537604e+05    18.812330    16.545432
# std    1.330461e+08  1.866909e+06    26.590545    69.625088
# min    3.000000e+01  2.020000e+00   -54.283545  -176.174022
# 25%    7.572605e+05  1.306600e+04     2.874467   -13.375923
# 50%    6.315500e+06  1.098840e+05    18.025227    16.725786
# 75%    2.268378e+07  4.817710e+05    41.315970    47.637577
# max    1.367110e+09  1.712444e+07    78.223156   179.118650

# %% [markdown]
# Checking Data Types of Columns

# %%
df.dtypes
# Out:
# country         object
# native_name     object
# iso2            object
# iso3            object
# population     float64
# area           float64
# capital         object
# capital_lat    float64
# capital_lng    float64
# region          object
# continent       object
# dtype: object

# %% [markdown]
# 5. Selecting Specific Columns in a DataFrame
#
# Selecting a Single Column

# %%
df['country']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                 Angola
#              ...
# 209    Wallis and Futuna
# 210       Western Sahara
# 211                Yemen
# 212               Zambia
# 213             Zimbabwe
# Name: country, Length: 214, dtype: object

# %% [markdown]
# Selecting Multiple Columns

# %%
df[['capital', 'region']]
# Out:
#        capital                     region
# 0        Kabul  Southern and Central Asia
# 1       Tirana            Southern Europe
# 2      Algiers            Northern Africa
# 3    Pago Pago                  Polynesia
# 4       Luanda             Central Africa
# ..         ...                        ...
# 209   Mata-Utu                  Polynesia
# 210   El Aaiún            Northern Africa
# 211     Sana'a                Middle East
# 212     Lusaka             Eastern Africa
# 213     Harare             Eastern Africa
#
# [214 rows x 2 columns]

# %% [markdown]
# Selecting Multiple Columns for a Specific Row Range

# %%
df[['population', 'area', 'capital']][15:210]
# Out:
#      population      area     capital
# 15    9475100.0  207600.0       Minsk
# 16   11225469.0   30528.0    Brussels
# 17     349728.0   22966.0    Belmopan
# 18    9988068.0  112622.0  Porto-Novo
# 19      64237.0      54.0    Hamilton
# ..          ...       ...         ...
# 205    264652.0   12189.0   Port Vila
# 206  30206307.0  916445.0     Caracas
# 207  89708900.0  331212.0       Hanoi
# 208         NaN       NaN         NaN
# 209     13135.0     142.0    Mata-Utu
#
# [195 rows x 3 columns]

# %%
df[['country', 'native_name', 'population']][5:211]
# Out:
#                  country          native_name  population
# 5               Anguilla             Anguilla     13452.0
# 6    Antigua and Barbuda  Antigua and Barbuda     86295.0
# 7              Argentina            Argentina  42669500.0
# 8                Armenia             Հայաստան   3009800.0
# 9                  Aruba                Aruba    101484.0
# ..                   ...                  ...         ...
# 206            Venezuela            Venezuela  30206307.0
# 207              Vietnam             Việt Nam  89708900.0
# 208                Wales                  NaN         NaN
# 209    Wallis and Futuna     Wallis et Futuna     13135.0
# 210       Western Sahara      الصحراء الغربية    586000.0
#
# [206 rows x 3 columns]

# %%
df[['country', 'iso3', 'iso2']][10:215]
# Out:
#                country iso3 iso2
# 10           Australia  AUS   AU
# 11             Austria  AUT   AT
# 12          Azerbaijan  AZE   AZ
# 13             Bahrain  BHR   BH
# 14          Bangladesh  BGD   BD
# ..                 ...  ...  ...
# 209  Wallis and Futuna  WLF   WF
# 210     Western Sahara  ESH   EH
# 211              Yemen  YEM   YE
# 212             Zambia  ZMB   ZM
# 213           Zimbabwe  ZWE   ZW
#
# [204 rows x 3 columns]

# %% [markdown]
# 6. Filtering Rows in a DataFrame
# Filtering Rows Based on a Condition

# %%
df[df['continent'] == 'Asia']
# Out:
#                   country                    native_name iso2 iso3  \
# 0             Afghanistan                      افغانستان   AF  AFG
# 8                 Armenia                       Հայաստան   AM  ARM
# 12             Azerbaijan                     Azərbaycan   AZ  AZE
# 13                Bahrain                       ‏البحرين   BH  BHR
# 14             Bangladesh                       বাংলাদেশ   BD  BGD
# 20                 Bhutan                      ʼbrug-yul   BT  BTN
# 25                 Brunei       Negara Brunei Darussalam   BN  BRN
# 29               Cambodia                      Kâmpŭchéa   KH  KHM
# 37                  China                             中国   CN  CHN
# 45                 Cyprus                         Κύπρος   CY  CYP
# 52             East Timor                    Timor-Leste   TL  TLS
# 67                Georgia                     საქართველო   GE  GEO
# 82              Hong Kong                             香港   HK  HKG
# 85                  India                           भारत   IN  IND
# 86              Indonesia                      Indonesia   ID  IDN
# 87                   Iran                           Irān   IR  IRN
# 88                   Iraq                         العراق   IQ  IRQ
# 91                 Israel                     יִשְׂרָאֵל   IL  ISR
# 95                  Japan                             日本   JP  JPN
# 97                 Jordan                         الأردن   JO  JOR
# 98             Kazakhstan                      Қазақстан   KZ  KAZ
# 101                Kuwait                         الكويت   KW  KWT
# 102            Kyrgyzstan                     Кыргызстан   KG  KGZ
# 103                  Laos                         ສປປລາວ   LA  LAO
# 105               Lebanon                          لبنان   LB  LBN
# 112                 Macau                             澳門   MO  MAC
# 116              Malaysia                       Malaysia   MY  MYS
# 117              Maldives                       Maldives   MV  MDV
# 127              Mongolia                     Монгол улс   MN  MNG
# 132                 Nepal                          नेपाल   NP  NPL
# 139           North Korea                             북한   KP  PRK
# 142                  Oman                           عمان   OM  OMN
# 143              Pakistan                       Pakistan   PK  PAK
# 147           Philippines                      Pilipinas   PH  PHL
# 151                 Qatar                            قطر   QA  QAT
# 162          Saudi Arabia               العربية السعودية   SA  SAU
# 167             Singapore                      Singapore   SG  SGP
# 174           South Korea                           대한민국   KR  KOR
# 177             Sri Lanka                    śrī laṃkāva   LK  LKA
# 184                 Syria                          سوريا   SY  SYR
# 187            Tajikistan                     Тоҷикистон   TJ  TJK
# 189              Thailand                      ประเทศไทย   TH  THA
# 195                Turkey                        Türkiye   TR  TUR
# 196          Turkmenistan                   Türkmenistan   TM  TKM
# 200  United Arab Emirates  دولة الإمارات العربية المتحدة   AE  ARE
# 204            Uzbekistan                    O‘zbekiston   UZ  UZB
# 207               Vietnam                       Việt Nam   VN  VNM
# 211                 Yemen                        اليَمَن   YE  YEM
#
#        population       area              capital  capital_lat  capital_lng  \
# 0    2.602310e+07   652230.0                Kabul    34.526011    69.177684
# 8    3.009800e+06    29743.0              Yerevan    40.177612    44.512585
# 12   9.552500e+06    86600.0                 Baku    40.375443    49.832675
# 13   1.316500e+06      765.0               Manama    26.223504    50.582244
# 14   1.574860e+08   147570.0                Dhaka    23.759357    90.378814
# 20   7.550300e+05    38394.0              Thimphu    27.472762    89.629548
# 25   3.933720e+05     5765.0  Bandar Seri Begawan     4.889545   114.941757
# 29   1.518412e+07   181035.0           Phnom Penh    11.568271   104.922443
# 37   1.367110e+09  9640011.0              Beijing    39.906217   116.391276
# 45   8.580000e+05     9251.0              Nicosia    35.173930    33.364726
# 52   1.172390e+06    14874.0                 Dili    28.651718    77.221939
# 67   4.490500e+06    69700.0              Tbilisi    41.693459    44.801450
# 82   7.234800e+06     1104.0     City of Victoria   -36.598610   144.678005
# 85   1.263930e+09  3287590.0            New Delhi    28.614179    77.202266
# 86   2.521648e+08  1904569.0              Jakarta    -6.175394   106.827183
# 87   7.796640e+07  1648195.0               Tehran    35.700618    51.401378
# 88   3.600455e+07   438317.0              Baghdad    33.302431    44.378799
# 91   8.268400e+06    20770.0            Jerusalem    31.778345    35.225079
# 95   1.270800e+08   377930.0                Tokyo    35.682839   139.759455
# 97   6.666960e+06    89342.0                Amman    31.951569    35.923962
# 98   1.737780e+07  2724900.0               Astana    51.128220    71.430668
# 101  3.268431e+06    17818.0          Kuwait City    29.379709    47.973563
# 102  5.776570e+06   199951.0              Bishkek    42.876562    74.607008
# 103  6.693300e+06   236800.0            Vientiane    17.964099   102.613371
# 105  4.104000e+06    10452.0               Beirut    33.895920    35.478430
# 112  6.310000e+05       30.0                  NaN          NaN          NaN
# 116  3.043050e+07   330803.0         Kuala Lumpur     3.151696   101.694237
# 117  3.412560e+05      300.0                 Malé    16.370036    -2.290024
# 127  2.987733e+06  1564110.0           Ulan Bator    47.918468   106.917702
# 132  2.764605e+07   147181.0            Kathmandu    27.708317    85.320582
# 139  2.502700e+07   120538.0            Pyongyang    39.019474   125.753388
# 142  4.089076e+06   309500.0               Muscat    23.599786    58.545130
# 143  1.884100e+08   881912.0            Islamabad    33.693812    73.065151
# 147  1.006974e+08   342353.0               Manila    14.590622   120.979970
# 151  2.269672e+06    11586.0                 Doha    25.285633    51.526416
# 162  3.077038e+07  2149690.0               Riyadh    24.631969    46.715065
# 167  5.469700e+06      710.0            Singapore     1.357107   103.819499
# 174  5.042396e+07   100210.0                Seoul    37.566679   126.978291
# 177  2.027760e+07    65610.0              Colombo     6.934997    79.853846
# 184  2.296432e+07   185180.0             Damascus    33.513070    36.309581
# 187  8.161000e+06   143100.0             Dushanbe    38.542584    68.815214
# 189  6.487100e+07   513120.0              Bangkok    13.754253   100.493087
# 195  7.666786e+07   783562.0               Ankara    39.920777    32.854067
# 196  5.838064e+06   488100.0             Ashgabat    37.939668    58.387426
# 200  9.446000e+06    83600.0            Abu Dhabi    24.474796    54.370576
# 204  3.049280e+07   447400.0             Tashkent    41.312336    69.278708
# 207  8.970890e+07   331212.0                Hanoi    21.029450   105.854444
# 211  2.595600e+07   527968.0               Sana'a    15.353857    44.205884
#
#                         region continent
# 0    Southern and Central Asia      Asia
# 8                  Middle East      Asia
# 12                 Middle East      Asia
# 13                 Middle East      Asia
# 14   Southern and Central Asia      Asia
# 20   Southern and Central Asia      Asia
# 25              Southeast Asia      Asia
# 29              Southeast Asia      Asia
# 37                Eastern Asia      Asia
# 45                 Middle East      Asia
# 52              Southeast Asia      Asia
# 67                 Middle East      Asia
# 82                Eastern Asia      Asia
# 85   Southern and Central Asia      Asia
# 86              Southeast Asia      Asia
# 87   Southern and Central Asia      Asia
# 88                 Middle East      Asia
# 91                 Middle East      Asia
# 95                Eastern Asia      Asia
# 97                 Middle East      Asia
# 98   Southern and Central Asia      Asia
# 101                Middle East      Asia
# 102  Southern and Central Asia      Asia
# 103             Southeast Asia      Asia
# 105                Middle East      Asia
# 112               Eastern Asia      Asia
# 116             Southeast Asia      Asia
# 117  Southern and Central Asia      Asia
# 127               Eastern Asia      Asia
# 132  Southern and Central Asia      Asia
# 139               Eastern Asia      Asia
# 142                Middle East      Asia
# 143  Southern and Central Asia      Asia
# 147             Southeast Asia      Asia
# 151                Middle East      Asia
# 162                Middle East      Asia
# 167             Southeast Asia      Asia
# 174               Eastern Asia      Asia
# 177             Southeast Asia      Asia
# 184                Middle East      Asia
# 187  Southern and Central Asia      Asia
# 189             Southeast Asia      Asia
# 195                Middle East      Asia
# 196  Southern and Central Asia      Asia
# 200                Middle East      Asia
# 204  Southern and Central Asia      Asia
# 207             Southeast Asia      Asia
# 211                Middle East      Asia

# %% [markdown]
# Filtering Rows to Exclude Specific Teams

# %%
df[~df['continent'].isin(["asia","Europe","Africa"])]
# Out:
#                  country          native_name iso2 iso3  population  \
# 0            Afghanistan            افغانستان   AF  AFG  26023100.0
# 3         American Samoa       American Samoa   AS  ASM     55519.0
# 5               Anguilla             Anguilla   AI  AIA     13452.0
# 6    Antigua and Barbuda  Antigua and Barbuda   AG  ATG     86295.0
# 7              Argentina            Argentina   AR  ARG  42669500.0
# ..                   ...                  ...  ...  ...         ...
# 205              Vanuatu              Vanuatu   VU  VUT    264652.0
# 206            Venezuela            Venezuela   VE  VEN  30206307.0
# 207              Vietnam             Việt Nam   VN  VNM  89708900.0
# 209    Wallis and Futuna     Wallis et Futuna   WF  WLF     13135.0
# 211                Yemen              اليَمَن   YE  YEM  25956000.0
#
#           area       capital  capital_lat  capital_lng  \
# 0     652230.0         Kabul    34.526011    69.177684
# 3        199.0     Pago Pago   -14.275479  -170.704830
# 5         91.0    The Valley    41.559572   -98.980548
# 6        442.0  Saint John's    47.561701   -52.715149
# 7    2780400.0  Buenos Aires   -34.607568   -58.437089
# ..         ...           ...          ...          ...
# 205    12189.0     Port Vila   -17.741497   168.315016
# 206   916445.0       Caracas    10.506098   -66.914602
# 207   331212.0         Hanoi    21.029450   105.854444
# 209      142.0      Mata-Utu   -13.282042  -176.174022
# 211   527968.0        Sana'a    15.353857    44.205884
#
#                         region      continent
# 0    Southern and Central Asia           Asia
# 3                    Polynesia        Oceania
# 5                    Caribbean  North America
# 6                    Caribbean  North America
# 7                South America  South America
# ..                         ...            ...
# 205                  Melanesia        Oceania
# 206              South America  South America
# 207             Southeast Asia           Asia
# 209                  Polynesia        Oceania
# 211                Middle East           Asia
#
# [117 rows x 11 columns]

# %% [markdown]
# Filtering Rows Where 'match_id' is Greater Than a Certain Value

# %%
df[df['area'] > 12189.0]
# Out:
#             country      native_name iso2 iso3  population       area  \
# 0       Afghanistan        افغانستان   AF  AFG  26023100.0   652230.0
# 1           Albania        Shqipëria   AL  ALB   2895947.0    28748.0
# 2           Algeria          الجزائر   DZ  DZA  38700000.0  2381741.0
# 4            Angola           Angola   AO  AGO  24383301.0  1246700.0
# 7         Argentina        Argentina   AR  ARG  42669500.0  2780400.0
# ..              ...              ...  ...  ...         ...        ...
# 207         Vietnam         Việt Nam   VN  VNM  89708900.0   331212.0
# 210  Western Sahara  الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211           Yemen          اليَمَن   YE  YEM  25956000.0   527968.0
# 212          Zambia           Zambia   ZM  ZMB  15023315.0   752612.0
# 213        Zimbabwe         Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#           capital  capital_lat  capital_lng                     region  \
# 0           Kabul    34.526011    69.177684  Southern and Central Asia
# 1          Tirana    41.326873    19.818791            Southern Europe
# 2         Algiers    36.775361     3.060188            Northern Africa
# 4          Luanda    -8.827270    13.243951             Central Africa
# 7    Buenos Aires   -34.607568   -58.437089              South America
# ..            ...          ...          ...                        ...
# 207         Hanoi    21.029450   105.854444             Southeast Asia
# 210      El Aaiún    27.154512   -13.195392            Northern Africa
# 211        Sana'a    15.353857    44.205884                Middle East
# 212        Lusaka   -15.416449    28.282154             Eastern Africa
# 213        Harare   -17.831773    31.045686             Eastern Africa
#
#          continent
# 0             Asia
# 1           Europe
# 2           Africa
# 4           Africa
# 7    South America
# ..             ...
# 207           Asia
# 210         Africa
# 211           Asia
# 212         Europe
# 213         Africa
#
# [155 rows x 11 columns]

# %% [markdown]
# 7. Counting Values in a DataFrame
# Counting Occurrences of a Specific Value in a Column

# %%
df[df['continent'] == "Asia"].shape[0]
# Out:
# 48

# %% [markdown]
# 8.Handling Missing Values
# Checking for Missing Values

# %%
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# country        0
# native_name    1
# iso2           1
# iso3           0
# population     4
# area           7
# capital        2
# capital_lat    2
# capital_lng    2
# region         9
# continent      8
# dtype: int64

# %% [markdown]
# Detecting Missing Values in the DataFrame

# %%
df.isnull()
# Out:
#      country  native_name   iso2   iso3  population   area  capital  \
# 0      False        False  False  False       False  False    False
# 1      False        False  False  False       False  False    False
# 2      False        False  False  False       False  False    False
# 3      False        False  False  False       False  False    False
# 4      False        False  False  False       False  False    False
# ..       ...          ...    ...    ...         ...    ...      ...
# 209    False        False  False  False       False  False    False
# 210    False        False  False  False       False  False    False
# 211    False        False  False  False       False  False    False
# 212    False        False  False  False       False  False    False
# 213    False        False  False  False       False  False    False
#
#      capital_lat  capital_lng  region  continent
# 0          False        False   False      False
# 1          False        False   False      False
# 2          False        False   False      False
# 3          False        False   False      False
# 4          False        False   False      False
# ..           ...          ...     ...        ...
# 209        False        False   False      False
# 210        False        False   False      False
# 211        False        False   False      False
# 212        False        False   False      False
# 213        False        False   False      False
#
# [214 rows x 11 columns]

# %% [markdown]
# Removing Rows with Missing Values

# %%
df.dropna()
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [194 rows x 11 columns]

# %%
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %% [markdown]
# Filling Missing Values

# %%
df.fillna(9)
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %%
df['country'] = df['country'].fillna(0)

# %%
df
# Out:
#                       native_name iso3  population   capital       capital  \
# iso2 country
# BE   Belgium               België  BEL  11225469.0   30528.0      Brussels
# CH   Switzerland          Schweiz  CHE   8183800.0   41284.0          Bern
# LI   Liechtenstein  Liechtenstein  LIE     37132.0     160.0         Vaduz
# LU   Luxembourg        Luxembourg  LUX    549700.0    2586.0    Luxembourg
# NL   Netherlands        Nederland  NLD  16881000.0   41850.0     Amsterdam
# ...                           ...  ...         ...       ...           ...
# CI   Ivory Coast    Côte d'Ivoire  CIV  23821000.0  322463.0  Yamoussoukro
# JE   Jersey                Jersey  JEY     99000.0     116.0  Saint Helier
# RS   Serbia                Srbija  SRB   7186862.0   49037.0      Belgrade
# TW   Taiwan                    臺灣  TWN  23424615.0   36193.0        Taipei
# GB   Wales                    NaN  GBR         NaN       NaN           NaN
#
#                     capital_lat  capital_lng          region continent
# iso2 country
# BE   Belgium          50.846557     4.351697  Western Europe    Europe
# CH   Switzerland      46.948271     7.451451  Western Europe    Europe
# LI   Liechtenstein    47.139286     9.522796  Western Europe    Europe
# LU   Luxembourg       49.815868     6.129675  Western Europe    Europe
# NL   Netherlands      52.372760     4.893604  Western Europe    Europe
# ...                         ...          ...             ...       ...
# CI   Ivory Coast       6.809107    -5.273263             NaN       NaN
# JE   Jersey           47.384387     4.683325             NaN       NaN
# RS   Serbia           44.817813    20.456897             NaN       NaN
# TW   Taiwan           25.037520   121.563680             NaN       NaN
# GB   Wales                  NaN          NaN             NaN    Europe
#
# [214 rows x 9 columns]

# %% [markdown]
# 9. Selecting Data using Indexing
# Integer-Based Indexing with iloc[]

# %%
df.iloc[10:233]
# Out:
#                country       native_name iso2 iso3   population       area  \
# 10           Australia         Australia   AU  AUS          NaN  7692024.0
# 11             Austria        Österreich   AT  AUT    8527230.0    83871.0
# 12          Azerbaijan        Azərbaycan   AZ  AZE    9552500.0    86600.0
# 13             Bahrain          ‏البحرين   BH  BHR    1316500.0      765.0
# 14          Bangladesh          বাংলাদেশ   BD  BGD  157486000.0   147570.0
# ..                 ...               ...  ...  ...          ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF      13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH     586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM   25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB   15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE   13061239.0   390757.0
#
#       capital  capital_lat  capital_lng                     region continent
# 10   Canberra   -35.297591   149.101268  Australia and New Zealand   Oceania
# 11     Vienna    48.208354    16.372504             Western Europe    Europe
# 12       Baku    40.375443    49.832675                Middle East      Asia
# 13     Manama    26.223504    50.582244                Middle East      Asia
# 14      Dhaka    23.759357    90.378814  Southern and Central Asia      Asia
# ..        ...          ...          ...                        ...       ...
# 209  Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210  El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211    Sana'a    15.353857    44.205884                Middle East      Asia
# 212    Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213    Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [204 rows x 11 columns]

# %%
df.iloc[33, 10]
# Out:
# 'North America'

# %%
df.iloc[0:2]
# Out:
#        country native_name iso2 iso3  population      area capital  \
# 0  Afghanistan   افغانستان   AF  AFG  26023100.0  652230.0   Kabul
# 1      Albania   Shqipëria   AL  ALB   2895947.0   28748.0  Tirana
#
#    capital_lat  capital_lng                     region continent
# 0    34.526011    69.177684  Southern and Central Asia      Asia
# 1    41.326873    19.818791            Southern Europe    Europe

# %%
df.iloc[0:3, 1:3]
# Out:
#   native_name iso2
# 0   افغانستان   AF
# 1   Shqipëria   AL
# 2     الجزائر   DZ

# %% [markdown]
# Label-Based Indexing with loc[]

# %%
print(df.loc[60])
# Out:
# country              Fiji
# native_name          Fiji
# iso2                   FJ
# iso3                  FJI
# population       859178.0
# area              18272.0
# capital              Suva
# capital_lat    -18.141588
# capital_lng    178.442166
# region          Melanesia
# continent         Oceania
# Name: 60, dtype: object

# %%
df.loc[[0, 100, 200]]
# Out:
#                   country                    native_name iso2 iso3  \
# 0             Afghanistan                      افغانستان   AF  AFG
# 100              Kiribati                       Kiribati   KI  KIR
# 200  United Arab Emirates  دولة الإمارات العربية المتحدة   AE  ARE
#
#      population      area       capital  capital_lat  capital_lng  \
# 0    26023100.0  652230.0         Kabul    34.526011    69.177684
# 100    106461.0     811.0  South Tarawa     1.349078   173.038651
# 200   9446000.0   83600.0     Abu Dhabi    24.474796    54.370576
#
#                         region continent
# 0    Southern and Central Asia      Asia
# 100                 Micronesia   Oceania
# 200                Middle East      Asia

# %%
print(df.loc[: "iso2"])
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %%
print(df.loc[:, ["iso2", "iso3"]])
# Out:
#     iso2 iso3
# 0     AF  AFG
# 1     AL  ALB
# 2     DZ  DZA
# 3     AS  ASM
# 4     AO  AGO
# ..   ...  ...
# 209   WF  WLF
# 210   EH  ESH
# 211   YE  YEM
# 212   ZM  ZMB
# 213   ZW  ZWE
#
# [214 rows x 2 columns]

# %% [markdown]
# 10.Filtering Data Using Conditions

# %%
print(df.loc[df["capital_lng"] == 9])
# Out:
# Empty DataFrame
# Columns: [country, native_name, iso2, iso3, population, area, capital, capital_lat, capital_lng, region, continent]
# Index: []

# %% [markdown]
# 11. Handling Duplicates
# Checking for Duplicates

# %%
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %% [markdown]
# Removing Duplicate Rows

# %%
df.drop_duplicates(inplace=True) # Remove duplicate rows permanently
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %% [markdown]
# 12. Adding and Removing Columns
# Adding a New Column

# %%
df['new_column2']=df['country']+df['native_name']
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent  \
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
#                            new_column2
# 0                 Afghanistanافغانستان
# 1                     AlbaniaShqipëria
# 2                       Algeriaالجزائر
# 3         American SamoaAmerican Samoa
# 4                         AngolaAngola
# ..                                 ...
# 209  Wallis and FutunaWallis et Futuna
# 210      Western Saharaالصحراء الغربية
# 211                       Yemenاليَمَن
# 212                       ZambiaZambia
# 213                   ZimbabweZimbabwe
#
# [214 rows x 12 columns]

# %% [markdown]
# Dropping a Column

# %%
df = df.drop('new_column2', axis=1)
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %%
df
# Out:
#                country       native_name iso2 iso3  population       area  \
# 0          Afghanistan         افغانستان   AF  AFG  26023100.0   652230.0
# 1              Albania         Shqipëria   AL  ALB   2895947.0    28748.0
# 2              Algeria           الجزائر   DZ  DZA  38700000.0  2381741.0
# 3       American Samoa    American Samoa   AS  ASM     55519.0      199.0
# 4               Angola            Angola   AO  AGO  24383301.0  1246700.0
# ..                 ...               ...  ...  ...         ...        ...
# 209  Wallis and Futuna  Wallis et Futuna   WF  WLF     13135.0      142.0
# 210     Western Sahara   الصحراء الغربية   EH  ESH    586000.0   266000.0
# 211              Yemen           اليَمَن   YE  YEM  25956000.0   527968.0
# 212             Zambia            Zambia   ZM  ZMB  15023315.0   752612.0
# 213           Zimbabwe          Zimbabwe   ZW  ZWE  13061239.0   390757.0
#
#        capital  capital_lat  capital_lng                     region continent
# 0        Kabul    34.526011    69.177684  Southern and Central Asia      Asia
# 1       Tirana    41.326873    19.818791            Southern Europe    Europe
# 2      Algiers    36.775361     3.060188            Northern Africa    Africa
# 3    Pago Pago   -14.275479  -170.704830                  Polynesia   Oceania
# 4       Luanda    -8.827270    13.243951             Central Africa    Africa
# ..         ...          ...          ...                        ...       ...
# 209   Mata-Utu   -13.282042  -176.174022                  Polynesia   Oceania
# 210   El Aaiún    27.154512   -13.195392            Northern Africa    Africa
# 211     Sana'a    15.353857    44.205884                Middle East      Asia
# 212     Lusaka   -15.416449    28.282154             Eastern Africa    Europe
# 213     Harare   -17.831773    31.045686             Eastern Africa    Africa
#
# [214 rows x 11 columns]

# %% [markdown]
# 13. Sorting Data
# Sorting by a Column

# %%
df=df.sort_values(by='region', ascending=False)
print("\nSorted Data by region:")
df
# Out:
# Sorted Data by region:
#            country    native_name iso2 iso3  population      area  \
# 16         Belgium         België   BE  BEL  11225469.0   30528.0
# 183    Switzerland        Schweiz   CH  CHE   8183800.0   41284.0
# 109  Liechtenstein  Liechtenstein   LI  LIE     37132.0     160.0
# 111     Luxembourg     Luxembourg   LU  LUX    549700.0    2586.0
# 133    Netherlands      Nederland   NL  NLD  16881000.0   41850.0
# ..             ...            ...  ...  ...         ...       ...
# 93     Ivory Coast  Côte d'Ivoire   CI  CIV  23821000.0  322463.0
# 96          Jersey         Jersey   JE  JEY     99000.0     116.0
# 164         Serbia         Srbija   RS  SRB   7186862.0   49037.0
# 186         Taiwan             臺灣   TW  TWN  23424615.0   36193.0
# 208          Wales            NaN   GB  GBR         NaN       NaN
#
#           capital  capital_lat  capital_lng          region continent
# 16       Brussels    50.846557     4.351697  Western Europe    Europe
# 183          Bern    46.948271     7.451451  Western Europe    Europe
# 109         Vaduz    47.139286     9.522796  Western Europe    Europe
# 111    Luxembourg    49.815868     6.129675  Western Europe    Europe
# 133     Amsterdam    52.372760     4.893604  Western Europe    Europe
# ..            ...          ...          ...             ...       ...
# 93   Yamoussoukro     6.809107    -5.273263             NaN       NaN
# 96   Saint Helier    47.384387     4.683325             NaN       NaN
# 164      Belgrade    44.817813    20.456897             NaN       NaN
# 186        Taipei    25.037520   121.563680             NaN       NaN
# 208           NaN          NaN          NaN             NaN    Europe
#
# [214 rows x 11 columns]

# %% [markdown]
# 14. Grouping and Aggregation
# Grouping by 'ball' and Calculating Aggregations

# %%
grouped_df = df.groupby('country')['area'].mean()
print("Mean of 'country'  by area:")
print(grouped_df)
# Out:
# Mean of 'country'  by area:
# country
# Afghanistan           652230.0
# Albania                28748.0
# Algeria              2381741.0
# American Samoa           199.0
# Angola               1246700.0
#                        ...
# Wallis and Futuna        142.0
# Western Sahara        266000.0
# Yemen                 527968.0
# Zambia                752612.0
# Zimbabwe              390757.0
# Name: area, Length: 214, dtype: float64

# %%
grouped_df = df.groupby('country')['area'].median()
print("Median of 'country' by area:")
print(grouped_df)
# Out:
# Median of 'country' by area:
# country
# Afghanistan           652230.0
# Albania                28748.0
# Algeria              2381741.0
# American Samoa           199.0
# Angola               1246700.0
#                        ...
# Wallis and Futuna        142.0
# Western Sahara        266000.0
# Yemen                 527968.0
# Zambia                752612.0
# Zimbabwe              390757.0
# Name: area, Length: 214, dtype: float64

# %%
grouped_df = df.groupby('country')['area'].var()
print("Variance of 'country' by area:")
print(grouped_df)
# Out:
# Variance of 'country' by area:
# country
# Afghanistan         NaN
# Albania             NaN
# Algeria             NaN
# American Samoa      NaN
# Angola              NaN
#                      ..
# Wallis and Futuna   NaN
# Western Sahara      NaN
# Yemen               NaN
# Zambia              NaN
# Zimbabwe            NaN
# Name: area, Length: 214, dtype: float64

# %%
grouped_df = df.groupby('country')['area'].std()
print("Standard Deviation of 'country'  by area:")
print(grouped_df)
# Out:
# Standard Deviation of 'country'  by area:
# country
# Afghanistan         NaN
# Albania             NaN
# Algeria             NaN
# American Samoa      NaN
# Angola              NaN
#                      ..
# Wallis and Futuna   NaN
# Western Sahara      NaN
# Yemen               NaN
# Zambia              NaN
# Zimbabwe            NaN
# Name: area, Length: 214, dtype: float64

# %% [markdown]
# 15. Renaming a Column

# %%
df = df.rename(columns={"area": "capital"})

# %% [markdown]
# 16. Resetting and Setting Index
# Setting a Multi-Level Index

# %%
df = df.set_index(["iso2", "country"])

# %%
df
# Out:
#                       native_name iso3  population   capital       capital  \
# iso2 country
# BE   Belgium               België  BEL  11225469.0   30528.0      Brussels
# CH   Switzerland          Schweiz  CHE   8183800.0   41284.0          Bern
# LI   Liechtenstein  Liechtenstein  LIE     37132.0     160.0         Vaduz
# LU   Luxembourg        Luxembourg  LUX    549700.0    2586.0    Luxembourg
# NL   Netherlands        Nederland  NLD  16881000.0   41850.0     Amsterdam
# ...                           ...  ...         ...       ...           ...
# CI   Ivory Coast    Côte d'Ivoire  CIV  23821000.0  322463.0  Yamoussoukro
# JE   Jersey                Jersey  JEY     99000.0     116.0  Saint Helier
# RS   Serbia                Srbija  SRB   7186862.0   49037.0      Belgrade
# TW   Taiwan                    臺灣  TWN  23424615.0   36193.0        Taipei
# GB   Wales                    NaN  GBR         NaN       NaN           NaN
#
#                     capital_lat  capital_lng          region continent
# iso2 country
# BE   Belgium          50.846557     4.351697  Western Europe    Europe
# CH   Switzerland      46.948271     7.451451  Western Europe    Europe
# LI   Liechtenstein    47.139286     9.522796  Western Europe    Europe
# LU   Luxembourg       49.815868     6.129675  Western Europe    Europe
# NL   Netherlands      52.372760     4.893604  Western Europe    Europe
# ...                         ...          ...             ...       ...
# CI   Ivory Coast       6.809107    -5.273263             NaN       NaN
# JE   Jersey           47.384387     4.683325             NaN       NaN
# RS   Serbia           44.817813    20.456897             NaN       NaN
# TW   Taiwan           25.037520   121.563680             NaN       NaN
# GB   Wales                  NaN          NaN             NaN    Europe
#
# [214 rows x 9 columns]

# %% [markdown]
# Resetting the Index

# %%
df = df.reset_index()

# %%
df
# Out:
#     iso2        country    native_name iso3  population   capital  \
# 0     BE        Belgium         België  BEL  11225469.0   30528.0
# 1     CH    Switzerland        Schweiz  CHE   8183800.0   41284.0
# 2     LI  Liechtenstein  Liechtenstein  LIE     37132.0     160.0
# 3     LU     Luxembourg     Luxembourg  LUX    549700.0    2586.0
# 4     NL    Netherlands      Nederland  NLD  16881000.0   41850.0
# ..   ...            ...            ...  ...         ...       ...
# 209   CI    Ivory Coast  Côte d'Ivoire  CIV  23821000.0  322463.0
# 210   JE         Jersey         Jersey  JEY     99000.0     116.0
# 211   RS         Serbia         Srbija  SRB   7186862.0   49037.0
# 212   TW         Taiwan             臺灣  TWN  23424615.0   36193.0
# 213   GB          Wales            NaN  GBR         NaN       NaN
#
#           capital  capital_lat  capital_lng          region continent
# 0        Brussels    50.846557     4.351697  Western Europe    Europe
# 1            Bern    46.948271     7.451451  Western Europe    Europe
# 2           Vaduz    47.139286     9.522796  Western Europe    Europe
# 3      Luxembourg    49.815868     6.129675  Western Europe    Europe
# 4       Amsterdam    52.372760     4.893604  Western Europe    Europe
# ..            ...          ...          ...             ...       ...
# 209  Yamoussoukro     6.809107    -5.273263             NaN       NaN
# 210  Saint Helier    47.384387     4.683325             NaN       NaN
# 211      Belgrade    44.817813    20.456897             NaN       NaN
# 212        Taipei    25.037520   121.563680             NaN       NaN
# 213           NaN          NaN          NaN             NaN    Europe
#
# [214 rows x 11 columns]

# %%
17. Get the dimensions of the DataFrame

# %%
df.shape
# Out:
# (214, 9)
